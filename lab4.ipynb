# %%
string = "Happy Birthday Jace"
array = list(string)
print(array)

for index, char in enumerate(array):
    if (index + 1) % 7 == 0:
        array[index] = 7

string = array.join("")
print(array)
# Out:
# ['H', 'a', 'p', 'p', 'y', ' ', 'B', 'i', 'r', 't', 'h', 'd', 'a', 'y', ' ', 'J', 'a', 'c', 'e']
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[19], line 9
#       5 for index, char in enumerate(array):
#       6     if (index + 1) % 7 == 0:
#       7         array[index] = 7
#       8
# ----> 9 string = array.join("")
#      10 print(array)
#
# AttributeError: 'list' object has no attribute 'join'
